# %%
import os
from os import path

data_dir = 'C:/Users/jay_s/PyTorch/3_Real_world_data/cat_images'          
# data_dir = os.getcwd()         # works
print(data_dir)          # C:\Users\jay_s\PyTorch\3_Real_world_data
# filenames = [name for name in os.listdir(data_dir) if os.path.splitext(name) == '.png']
for name in os.listdir(data_dir):
     print(name)
     txt = os.path.splitext(name)
     print(txt)
     # print(txt[1])
     #print((os.path.splitext(name)).1)
     if txt[1] == '.png':
        filenames = name
        
# print(filenames)

     
l1 = ["eat", "sleep", "repeat"]
  
# printing the tuples in object directly
for ele in enumerate(l1):
    print (ele)
    
for i, ele in enumerate(l1):
    print (ele)
# Out:
# C:/Users/jay_s/PyTorch/3_Real_world_data/cat_images
# cat1.png
# ('cat1', '.png')
# cat2.png
# ('cat2', '.png')
# cat3.png
# ('cat3', '.png')
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')
# eat
# sleep
# repeat

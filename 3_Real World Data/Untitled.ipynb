# %%
import torch

x = torch.randn(4, 4)

# %%
x
# Out:
# tensor([[-0.7833, -0.4302,  0.0126,  0.9913],
#         [ 1.6975, -0.8596, -0.3294,  0.2634],
#         [-0.2140, -0.3870, -0.0892,  0.1773],
#         [ 1.2334,  0.5541, -1.8182, -0.2442]])

# %%
x.size()
# Out:
# torch.Size([4, 4])

# %%
y = x.view(16)

# %%
y.size()
# Out:
# torch.Size([16])

# %%
y
# Out:
# tensor([-0.7833, -0.4302,  0.0126,  0.9913,  1.6975, -0.8596, -0.3294,  0.2634,
#         -0.2140, -0.3870, -0.0892,  0.1773,  1.2334,  0.5541, -1.8182, -0.2442])

# %%
y.shape
# Out:
# torch.Size([16])

# %%
y.stride()
# Out:
# (1,)

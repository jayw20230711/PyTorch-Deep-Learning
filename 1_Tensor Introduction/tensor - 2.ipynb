# %%
import torch

points = torch.zeros(6)

# %%
points[0] = 2
points[1] = 3.0

points
# Out:
# tensor([2., 3., 0., 0., 0., 0.])

# %%
points = torch.tensor([2, 3.0, 0, 0, 0])
points
# Out:
# tensor([2., 3., 0., 0., 0.])

# %%
points[0]
# Out:
# tensor(2.)

# %%
float(points[0])
# Out:
# 2.0

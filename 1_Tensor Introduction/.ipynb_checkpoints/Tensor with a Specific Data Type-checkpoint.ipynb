# %%
import torch

# Specify the data type (e.g., float32, int64)
float_tensor = torch.tensor([1.0, 2.0, 3.0], dtype=torch.float32)
float_tensor
# Out:
# tensor([1., 2., 3.])

# %%
float_tensor.type()
# Out:
# 'torch.FloatTensor'

# %%
int_tensor = torch.tensor([1, 2, 3], dtype=torch.int64)
int_tensor
# Out:
# tensor([1, 2, 3])

# %%
int_tensor.type()
# Out:
# 'torch.LongTensor'

# %%
int_tensor2 = torch.tensor([1, 2, 3])
int_tensor2
# Out:
# tensor([1, 2, 3])

# %%
int_tensor2.type()
# Out:
# 'torch.LongTensor'
